# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamedelhacen/covid19/blob/master/covid19_radiography.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Downloading and Extracting Data

# %%
! pip install kaggle
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
# Out:
# ...
# mkdir: /Users/hacen/.kaggle: File exists

# %%
# !kaggle datasets download -d preetviradiya/covid19-radiography-dataset
# Out:
# ...
# 100%|████████████████████████████████████████| 747M/747M [05:43<00:00, 2.08MB/s]
# 100%|████████████████████████████████████████| 747M/747M [05:43<00:00, 2.28MB/s]

# %%
! unzip covid19-radiography-dataset.zip
# Out:
# Archive:  covid19-radiography-dataset.zip
#   inflating: COVID-19_Radiography_Dataset/COVID-19_Radiography_Dataset/COVID/COVID-1.png
#   inflating: COVID-19_Radiography_Dataset/COVID-19_Radiography_Dataset/COVID/COVID-10.png
#   inflating: COVID-19_Radiography_Dataset/COVID-19_Radiography_Dataset/COVID/COVID-100.png
#   inflating: COVID-19_Radiography_Dataset/COVID-19_Radiography_Dataset/COVID/COVID-1000.png
#   inflating: COVID-19_Radiography_Dataset/COVID-19_Radiography_Dataset/COVID/COVID-1001.png
#   inflating: COVID-19_Radiography_Dataset/COVID-19_Radiography_Dataset/COVID/COVID-1002.png
#   inflating: COVID-19_Radiography_Dataset/COVID-19_Radiography_Dataset/COVID/COVID-1003.png
#   inflating: COVID-19_Radiography_Dataset/COVID-19_Radiography_Dataset/COVID/COVID-1004.png
#   inflating: COVID-19_Radiography_Dataset/COVID-19_Radiography_Dataset/COVID/COVID-1005.png
#   inflating: COVID-19_Radiography_Dataset/COVID-19_Radiography_Dataset/COVID/COVID-1006.png
# ...

# %% [markdown]
# # Preprocessing Data

# %%
import os
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### From directories

# %%
data_dir = "COVID-19_Radiography_Dataset/COVID-19_Radiography_Dataset"
class_names = os.listdir(data_dir)
class_names
# Out:
# ['Viral Pneumonia', 'Lung_Opacity', 'Normal', 'COVID']

# %%
image_files = [[os.path.join(data_dir, class_name, x) 
               for x in os.listdir(os.path.join(data_dir, class_name))] 
               for class_name in class_names]
len(image_files)
# Out:
# 4

# %%
len(image_files[0]), len(image_files[1]), len(image_files[2]), len(image_files[3])
# Out:
# (1345, 6012, 10192, 3616)

# %%
image_file_list = []
image_label_list = []

for i, class_name in enumerate(class_names):
    image_file_list.extend(image_files[i])
    image_label_list.extend([i] * len(image_files[i]))
num_total = len(image_label_list)
num_total
# Out:
# 21165

# %%
image_label_names = []
for i in range(len(image_label_list)):
    if image_label_list[i] == 0:
        image_label_names.append(class_names[0])    
    elif image_label_list[i] == 1:
        image_label_names.append(class_names[1])
    elif image_label_list[i] == 2:
        image_label_names.append(class_names[2])
    elif image_label_list[i] == 3:
        image_label_names.append(class_names[3])
image_label_names
# Out:
# ['Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
#  'Viral Pneumonia',
# ...

# %% [markdown]
# ### From CSV file

# %%
data = pd.read_csv('metadata.csv', index_col=0)
data.head()
# Out:
#         file_name                               image_data_grayscale  \
# 0     COVID-1.png  [[185  40   0 ...   0  24 131]\n [ 75  14   0 ...
# 1    COVID-10.png  [[135 133 131 ...  24  21  19]\n [132 130 129 ...
# 2   COVID-100.png  [[ 62  10   0 ... 197 200 209]\n [ 35   6   0 ...
# 3  COVID-1000.png  [[162 162 162 ...   4   4   5]\n [ 26  26  26 ...
# 4  COVID-1001.png  [[  0   0   0 ...   0   0   0]\n [  0   0   0 ...
#
#   file_format image_shape  label
# 0         PNG  (299, 299)  COVID
# 1         PNG  (299, 299)  COVID
# 2         PNG  (299, 299)  COVID
# 3         PNG  (299, 299)  COVID
# 4         PNG  (299, 299)  COVID

# %%
data['image_data_grayscale'][0]
# Out:
# '[[185  40   0 ...   0  24 131]\n [ 75  14   0 ...   0   8  42]\n [ 11   2   0 ...   1   3  12]\n ...\n [ 78  62  68 ...   3  13  27]\n [104  74  75 ...   1  23  83]\n [156  90  78 ...   1  45 167]]'

# %%
print(data['image_data_grayscale'][0])
# Out:
# [[185  40   0 ...   0  24 131]
#  [ 75  14   0 ...   0   8  42]
#  [ 11   2   0 ...   1   3  12]
#  ...
#  [ 78  62  68 ...   3  13  27]
#  [104  74  75 ...   1  23  83]
#  [156  90  78 ...   1  45 167]]

# %%
data.value_counts()
# Out:
# file_name                image_data_grayscale                                                                                                                                                                                   file_format  image_shape  label
# COVID-1.png              [[185  40   0 ...   0  24 131]\n [ 75  14   0 ...   0   8  42]\n [ 11   2   0 ...   1   3  12]\n ...\n [ 78  62  68 ...   3  13  27]\n [104  74  75 ...   1  23  83]\n [156  90  78 ...   1  45 167]]  PNG          (299, 299)   COVID              1
# Normal-4865.png          [[134 131 122 ...   0   0   0]\n [127 115  84 ...   0   0   0]\n [117  92  50 ...   0   0   0]\n ...\n [163 119  54 ...   0   0   0]\n [167 123  57 ...   0   0   0]\n [170 124  59 ...   0   0   0]]  PNG          (299, 299)   Normal             1
# ...

# %% [markdown]
# # Visaulization

# %%
pd.DataFrame(image_label_names)
# Out:
#                      0
# 0      Viral Pneumonia
# 1      Viral Pneumonia
# 2      Viral Pneumonia
# 3      Viral Pneumonia
# 4      Viral Pneumonia
# ...                ...
# 21160            COVID
# 21161            COVID
# 21162            COVID
# 21163            COVID
# 21164            COVID
#
# [21165 rows x 1 columns]

# %%
class_names
# Out:
# ['Viral Pneumonia', 'Lung_Opacity', 'Normal', 'COVID']

# %%
sx = sns.countplot(image_label_names)
sx.set_xticklabels(labels=sx.get_xticklabels(), rotation=90)
plt.show()

# for i in range(4):
#     print(class_names[i], len(image_files[i]))
# Out:
# /Users/hacen/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
for i in range(len(image_files)):
    for j in range(4):
        image = plt.imread(image_files[i][random.randint(0, len(image_files[i]))])
        plt.subplot(4, 4, i*4+j+1)
        plt.imshow(image, cmap='gray')
        plt.axis('off')
        plt.title(class_names[i], fontdict={'fontsize':8})

# %%
random.randint(0, len(image_files[1]))
# Out:
# 2744

# %%
rand()
